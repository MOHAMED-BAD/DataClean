# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
climate=pd.read_excel('climate_change_download_0.xls')
climate.head()
# Out:
#   Country code Country name     Series code  \
# 0          ABW        Aruba  AG.LND.EL5M.ZS
# 1          ADO      Andorra  AG.LND.EL5M.ZS
# 2          AFG  Afghanistan  AG.LND.EL5M.ZS
# 3          AGO       Angola  AG.LND.EL5M.ZS
# 4          ALB      Albania  AG.LND.EL5M.ZS
#
#                            Series name SCALE Decimals      1990 1991 1992  \
# 0  Land area below 5m (% of land area)     0        1   29.5748   ..   ..
# 1  Land area below 5m (% of land area)     0        1         0   ..   ..
# 2  Land area below 5m (% of land area)     0        1         0   ..   ..
# 3  Land area below 5m (% of land area)     0        1  0.208235   ..   ..
# 4  Land area below 5m (% of land area)     0        1   4.96788   ..   ..
#
#   1993  ... 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011
# 0   ..  ...   ..   ..   ..   ..   ..   ..   ..   ..   ..   ..
# 1   ..  ...   ..   ..   ..   ..   ..   ..   ..   ..   ..   ..
# 2   ..  ...   ..   ..   ..   ..   ..   ..   ..   ..   ..   ..
# ...

# %% [markdown]
# # Learn about data

# %%
climate.columns
# Out:
# Index(['Country code', 'Country name',  'Series code',  'Series name',
#               'SCALE',     'Decimals',           1990,           1991,
#                  1992,           1993,           1994,           1995,
#                  1996,           1997,           1998,           1999,
#                  2000,           2001,           2002,           2003,
#                  2004,           2005,           2006,           2007,
#                  2008,           2009,           2010,           2011],
#       dtype='object')

# %%
climate.index
# Out:
# RangeIndex(start=0, stop=13512, step=1)

# %%
climate.values
# Out:
# array([['ABW', 'Aruba', 'AG.LND.EL5M.ZS', ..., '..', '..', '..'],
#        ['ADO', 'Andorra', 'AG.LND.EL5M.ZS', ..., '..', '..', '..'],
#        ['AFG', 'Afghanistan', 'AG.LND.EL5M.ZS', ..., '..', '..', '..'],
#        ...,
#        ['ZAR', 'Congo, Dem. Rep.', 'SP.URB.TOTL', ..., 22201848.3232,
#         23219959.84, '..'],
#        ['ZMB', 'Zambia', 'SP.URB.TOTL', ..., 4524564.0776, 4614728.013,
#         '..'],
#        ['ZWE', 'Zimbabwe', 'SP.URB.TOTL', ..., 4717663.7744, 4814866.882,
#         '..']], dtype=object)

# %%
climate.shape
# Out:
# (13512, 28)

# %%
type(climate)
# Out:
# pandas.core.frame.DataFrame

# %%
climate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13512 entries, 0 to 13511
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country code  13512 non-null  object
#  1   Country name  13512 non-null  object
#  2   Series code   13512 non-null  object
#  3   Series name   13512 non-null  object
#  4   SCALE         13512 non-null  object
#  5   Decimals      13512 non-null  object
#  6   1990          10017 non-null  object
#  7   1991          10017 non-null  object
#  8   1992          10017 non-null  object
#  9   1993          10017 non-null  object
#  10  1994          10017 non-null  object
#  11  1995          10017 non-null  object
#  12  1996          10017 non-null  object
#  13  1997          10017 non-null  object
#  14  1998          10017 non-null  object
#  15  1999          10017 non-null  object
#  16  2000          10017 non-null  object
#  17  2001          10017 non-null  object
# ...

# %% [markdown]
# # Drop inconsistencies

# %%
climate=climate.drop([2011],axis=1)

# %%
climate=climate.drop(['SCALE'],axis=1)

# %%
climate=climate.drop(['Decimals'],axis=1)

# %% [markdown]
# # drop values

# %%
climate.isnull().sum().sum()
# Out:
# 73395

# %%
climatclimate.dropna()
# Out:
#       Country code      Country name     Series code  \
# 0              ABW             Aruba  AG.LND.EL5M.ZS
# 1              ADO           Andorra  AG.LND.EL5M.ZS
# 2              AFG       Afghanistan  AG.LND.EL5M.ZS
# 3              AGO            Angola  AG.LND.EL5M.ZS
# 4              ALB           Albania  AG.LND.EL5M.ZS
# ...            ...               ...             ...
# 13507          YEM       Yemen, Rep.     SP.URB.TOTL
# 13508          ZAF      South Africa     SP.URB.TOTL
# 13509          ZAR  Congo, Dem. Rep.     SP.URB.TOTL
# 13510          ZMB            Zambia     SP.URB.TOTL
# 13511          ZWE          Zimbabwe     SP.URB.TOTL
#
#                                Series name         1990         1991  \
# 0      Land area below 5m (% of land area)      29.5748           ..
# 1      Land area below 5m (% of land area)            0           ..
# 2      Land area below 5m (% of land area)            0           ..
# ...

# %% [markdown]
# # Fixed Values

# %%
for i in range (1990,2011,1):
    climate[i]=climate[i].replace('..',0)

# %%
climate
# Out:
#       Country code      Country name     Series code  \
# 0              ABW             Aruba  AG.LND.EL5M.ZS
# 1              ADO           Andorra  AG.LND.EL5M.ZS
# 2              AFG       Afghanistan  AG.LND.EL5M.ZS
# 3              AGO            Angola  AG.LND.EL5M.ZS
# 4              ALB           Albania  AG.LND.EL5M.ZS
# ...            ...               ...             ...
# 13507          YEM       Yemen, Rep.     SP.URB.TOTL
# 13508          ZAF      South Africa     SP.URB.TOTL
# 13509          ZAR  Congo, Dem. Rep.     SP.URB.TOTL
# 13510          ZMB            Zambia     SP.URB.TOTL
# 13511          ZWE          Zimbabwe     SP.URB.TOTL
#
#                                Series name          1990          1991  \
# 0      Land area below 5m (% of land area)  2.957481e+01  0.000000e+00
# 1      Land area below 5m (% of land area)  0.000000e+00  0.000000e+00
# 2      Land area below 5m (% of land area)  0.000000e+00  0.000000e+00
# ...

# %% [markdown]
# # Duplicated

# %%
duplicates =climate.duplicated(subset=['Country name'])

# %%
climate[duplicates].sort_values(by='Country name')
# Out:
#       Country code Country name           Series code  \
# 2332           AFG  Afghanistan     EN.ATM.GHGO.KT.CE
# 8157           AFG  Afghanistan        IC.BUS.EASE.XQ
# 3264           AFG  Afghanistan        EN.CLC.DRSK.XQ
# 1400           AFG  Afghanistan     EG.USE.PCAP.KG.OE
# 10487          AFG  Afghanistan        SE.PRM.CMPT.ZS
# ...            ...          ...                   ...
# 12348          ZWE     Zimbabwe        SH.STA.MALN.ZS
# 11416          ZWE     Zimbabwe        SH.MED.NUMW.P3
# 2329           ZWE     Zimbabwe  EN.ATM.CO2E.PP.GD.KD
# 8387           ZWE     Zimbabwe        IC.BUS.EASE.XQ
# 13511          ZWE     Zimbabwe           SP.URB.TOTL
#
#                                              Series name        1990  \
# 2332                 Other GHG emissions, total (KtCO2e)        0.00
# 8157      Ease of doing business (ranking 1-183; 1=best)        0.00
# 3264   Disaster risk reduction progress score (1-5 sc...        0.00
# ...

# %%
climate=climate.set_index(['Series code','Series name'])

# %%
climate.sort_values(by='Country name')
# Out:
#                                                                   Country code  \
# Series code    Series name
# EN.CLC.PCAT.C  Projected annual temperature change (2045-2065,...          AFG
# EN.CLC.PCCC    Projected change in annual cool days/cold nights            AFG
# SH.MLR.INCD    Malaria incidence rate (per 100,000 people)                 AFG
# EN.POP.EL5M.ZS Population below 5m (% of total)                            AFG
# EN.CLC.MDAT.ZS Droughts, floods, extreme temps (% pop. avg. 19...          AFG
# ...                                                                        ...
# ER.H2O.FWTL.ZS Annual freshwater withdrawals (% of internal re...          ZWE
# ER.LND.PTLD.ZS Nationally terrestrial protected areas (% of to...          ZWE
# IC.BUS.EASE.XQ Ease of doing business (ranking 1-183; 1=best)              ZWE
# EN.CLC.PCHW    Projected change in annual hot days/warm nights             ZWE
# ...

# %% [markdown]
# # Merging Values

# %%
summaries={}
for i in range (1990,2011,1):
    summaries[i]='sum'

# %%
column_names=['Country code','Country name']
climate =climate.groupby(by = column_names).agg(summaries).reset_index()

# %%
climate.plot()
